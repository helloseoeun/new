# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
df = pd.read_csv('tmdb_5000_credits.csv/tmdb_5000_credits.csv' ,sep=',',dtype='unicode')

movie=df.groupby('title')

fig = plt.figure()
axe = fig.add_subplot(1,1,1)
axe.hist(['movie','cast','crew','title'],bins=10)

axe.set_title('movie',fontsize=20)
plt.xlabel('genre',fontsize=15)
plt.ylabel('reservation_rate & rating',fontsize=15)
# Out:
# Text(0, 0.5, 'reservation_rate & rating')
